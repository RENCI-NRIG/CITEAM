# %% [markdown]
# #  Microscopy Image Processing Basics (PR101)
#
# Welcome to the ** Microscopy Image Processing Basics** component of the CITeams training materials. The intent behind this unit is to walk you through on how you can use popular packages in python to do some image processing on the TEM data. In this notebook we use the following
#
# * numpy
# * matplotlib
# * scikit-learn a free and open-source machine learning library for the Python programming language.
#
#
# You're currently looking at [PRE101 Introduction](PRE101-Introduction.ipynb).
#
# - [PRE101](PRE101.ipynb) - TEM Hands‑on  Processing.
